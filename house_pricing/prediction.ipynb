# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import linear_model
import pickle
import joblib
df = pd.read_csv(r'C:\Users\malia\OneDrive\Desktop\Machine learning\house_pricing\homeprices.csv')
print(df.head())
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'],df['price'],color='b', marker='*')
plt.xlabel('area')
plt.ylabel('price')
plt.show()

# %%
new_df=df.drop('price',axis='columns')
price=df['price']

# %%
reg=joblib.load(r'C:\Users\malia\OneDrive\Desktop\Machine learning\house_pricing\modle_joblib')
print(reg.predict([[3300]]))
# Out:
# [628715.75342466]
# c:\Users\malia\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df1=pd.read_csv(r'C:\Users\malia\OneDrive\Desktop\Machine learning\house_pricing\areas.csv')

df1['price']=reg.predict(df1)
print(df1.head())
# Out:
#    area          price
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836
